# %% [markdown]
# ### Visualize COCO conversion

# %%
from coco_utils import coco_labels_utils as clu
from coco_utils import coco_viz_utils as cvu

# %%
help(cvu)
# Out:
# Help on module coco_utils.coco_viz_utils in coco_utils:
#
# NAME
#     coco_utils.coco_viz_utils - COCO Visualization Utilities.
#
# DESCRIPTION
#     This module provides functions to visualize COCO dataset annotations,
#     including bounding boxes and keypoints, on their corresponding images.
#     It depends on PIL (Pillow) and Matplotlib.
#
# FUNCTIONS
#     find_annotations(data: Dict, image_id: int) -> List[Dict]
#         Finds all annotations for a given image_id.
#
#         Args:
#             data: The loaded COCO dataset dictionary.
#             image_id: The ID of the image whose annotations are sought.
#
#         Returns:
#             A list of annotation dictionaries for the given image_id.
#
#     find_image_info(data: Dict, image_id: int) -> Union[Dict, NoneType]
#         Finds the image dictionary for a given image_id.
#
#         Args:
#             data: The loaded COCO dataset dictionary.
#             image_id: The ID of the image to find.
#
#         Returns:
#             The dictionary containing image info, or None if not found.
#
#     visualize_bbox(coco_data: Dict, image_id: int, image_dir: str, box_color: str = 'red', box_width: int = 3) -> None
#         Visualizes **all** bounding boxes found for a given image_id.
#
#         Args:
#             coco_data: Loaded COCO data as a Python dictionary.
#             image_id: The ID of the image to visualize.
#             image_dir: The directory containing the image files referenced in coco_data.
#             box_color: Color for the bounding box outlines.
#             box_width: Width of the bounding box outlines.
#
#     visualize_keypoints(coco_data: Dict, image_id: int, image_dir: str, point_colors: List[str] = ['blue', 'red', 'green'], point_radius: int = 5, skeleton_color: str = 'white', line_width: int = 2) -> None
#         Visualizes keypoints and skeleton for a given image_id in COCO format.
#
#         Uses specified colors (default: blue, red, green) for keypoints of the
#         first few detected individuals (up to len(point_colors)).
#         Draws skeleton connections if defined in categories.
#
#         Args:
#             coco_data: Loaded COCO data as a Python dictionary.
#             image_id: The ID of the image to visualize.
#             image_dir: The directory containing the image files.
#             point_colors: List of colors to cycle through for different individuals.
#             point_radius: Radius of the drawn keypoints.
#             skeleton_color: Color for the skeleton lines.
#             line_width: Width of the skeleton lines.
#
# DATA
#     Dict = typing.Dict
#     List = typing.List
#     Optional = typing.Optional
#     Tuple = typing.Tuple
#
# FILE
#     c:\programdata\miniconda3\envs\chairnp\lib\site-packages\coco_utils\coco_viz_utils.py

# %%
coco_json = r"A:\EnclosureProjects\inprep\freemat\code\calibration\WMcalibration\Label3D\labeling_output\output_coco.json"

coco_data = clu.load_coco_data(coco_json)

# extract first image from video 
cam_001 = r"A:\EnclosureProjects\inprep\freemat\data\experiments\good\240528\video\experiment\fixed_timestamp\crop1min_cropped_videos\Cam_001.mp4"

import cv2 

cap = cv2.VideoCapture(cam_001)
ret, frame = cap.read()
# display frame
cv2.imshow("Frame", frame)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# cv2.imwrite(r"A:\EnclosureProjects\inprep\freemat\code\calibration\WMcalibration\Label3D\labeling_output\images\Cam_001_frame_000001.jpg", frame)

cvu.visualize_bbox(coco_data, 1, r"A:\EnclosureProjects\inprep\freemat\code\calibration\WMcalibration\Label3D\labeling_output\images")
cvu.visualize_keypoints(coco_data, 1, r"A:\EnclosureProjects\inprep\freemat\code\calibration\WMcalibration\Label3D\labeling_output\images")
# Out:
# Drawing bbox [93, 741, 228, 134] for annotation ID 1 on image ID 1.
# Drawing bbox [1328, 674, 216, 404] for annotation ID 2 on image ID 1.
# Found category 'monkey' (ID: 1) with 17 keypoints and 18 skeleton connections.
# Visualizing keypoints for 2 individual(s) out of 2 found.
#   Individual 1 (Ann ID: 1): Color blue
#     Drawn 17 visible keypoints (out of 17 total labeled points).
#     Warning: Invalid skeleton connection indices [0, 1] for keypoint list length 17.
#     Warning: Invalid skeleton connection indices [0, 2] for keypoint list length 17.
#     Drawn 16 skeleton connections.
#   Individual 2 (Ann ID: 2): Color red
#     Drawn 14 visible keypoints (out of 17 total labeled points).
#     Warning: Invalid skeleton connection indices [0, 1] for keypoint list length 17.
#     Warning: Invalid skeleton connection indices [0, 2] for keypoint list length 17.
#     Drawn 9 skeleton connections.
